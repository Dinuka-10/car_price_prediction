# %%
import pandas as pd

# %% [markdown]
# ## Load dataset ##

# %%
data = pd.read_csv("cardataset.csv")

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Individual       Manual   First Owner               23.40  1248.0
# 1  Individual       Manual  Second Owner               21.14  1498.0
# 2  Individual       Manual   Third Owner               17.70  1497.0
# 3  Individual       Manual   First Owner               23.00  1396.0
# 4  Individual       Manual   First Owner               16.10  1298.0
#
#   max_power  seats
# 0        74    5.0
# 1    103.52    5.0
# 2        78    5.0
# 3        90    5.0
# ...

# %%
data.shape
# Out:
# (8128, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                8128 non-null   object
#  1   year                8128 non-null   int64
#  2   selling_price       8128 non-null   int64
#  3   km_driven           8128 non-null   int64
#  4   fuel                8128 non-null   object
#  5   seller_type         8128 non-null   object
#  6   transmission        8128 non-null   object
#  7   owner               8128 non-null   object
#  8   mileage(km/ltr/kg)  7907 non-null   float64
#  9   engine              7907 non-null   float64
#  10  max_power           7913 non-null   object
#  11  seats               7907 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 762.1+ KB

# %%
data.describe()
# Out:
#               year  selling_price     km_driven  mileage(km/ltr/kg)  \
# count  8128.000000   8.128000e+03  8.128000e+03         7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04           19.418783
# std       4.044249   8.062534e+05  5.655055e+04            4.037145
# min    1983.000000   2.999900e+04  1.000000e+00            0.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04           16.780000
# 50%    2015.000000   4.500000e+05  6.000000e+04           19.300000
# 75%    2017.000000   6.750000e+05  9.800000e+04           22.320000
# max    2020.000000   1.000000e+07  2.360457e+06           42.000000
#
#             engine        seats
# count  7907.000000  7907.000000
# mean   1458.625016     5.416719
# std     503.916303     0.959588
# min     624.000000     2.000000
# 25%    1197.000000     5.000000
# 50%    1248.000000     5.000000
# 75%    1582.000000     5.000000
# max    3604.000000    14.000000

# %% [markdown]
# ## Handle null values ##

# %%
data.head(3)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
#
#   seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Individual       Manual   First Owner               23.40  1248.0
# 1  Individual       Manual  Second Owner               21.14  1498.0
# 2  Individual       Manual   Third Owner               17.70  1497.0
#
#   max_power  seats
# 0        74    5.0
# 1    103.52    5.0
# 2        78    5.0

# %%
data.isnull().sum()
# Out:
# name                    0
# year                    0
# selling_price           0
# km_driven               0
# fuel                    0
# seller_type             0
# transmission            0
# owner                   0
# mileage(km/ltr/kg)    221
# engine                221
# max_power             215
# seats                 221
# dtype: int64

# %%
# mileage(km/ltr/kg)
data['mileage(km/ltr/kg)'] = data['mileage(km/ltr/kg)'].fillna(data['mileage(km/ltr/kg)'].median())

#engine
data['engine'] = data['engine'].fillna(data['engine'].median())

#max_power
data['max_power'] = pd.to_numeric(data['max_power'], errors='coerce')
data['max_power'] = data['max_power'].fillna(data['max_power'].median())

#seats
data['seats'] = data['seats'].fillna(data['seats'].median())

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Individual       Manual   First Owner               23.40  1248.0
# 1  Individual       Manual  Second Owner               21.14  1498.0
# 2  Individual       Manual   Third Owner               17.70  1497.0
# 3  Individual       Manual   First Owner               23.00  1396.0
# 4  Individual       Manual   First Owner               16.10  1298.0
#
#    max_power  seats
# 0      74.00    5.0
# 1     103.52    5.0
# 2      78.00    5.0
# 3      90.00    5.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                8128 non-null   object
#  1   year                8128 non-null   int64
#  2   selling_price       8128 non-null   int64
#  3   km_driven           8128 non-null   int64
#  4   fuel                8128 non-null   object
#  5   seller_type         8128 non-null   object
#  6   transmission        8128 non-null   object
#  7   owner               8128 non-null   object
#  8   mileage(km/ltr/kg)  8128 non-null   float64
#  9   engine              8128 non-null   float64
#  10  max_power           8128 non-null   float64
#  11  seats               8128 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 762.1+ KB

# %%
data.isnull().sum()
# Out:
# name                  0
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage(km/ltr/kg)    0
# engine                0
# max_power             0
# seats                 0
# dtype: int64

# %% [markdown]
# #### 'name' column ####

# %%
data['brand'] = data['name'].apply(lambda x: x.split(' ')[0])
data['model'] = data['name'].apply(lambda x: ' '.join(x.split(' ')[1:2]))
data['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Ambassador          4
# Kia                 4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
data = data.drop('name', axis=1)

# %%
data.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner  mileage(km/ltr/kg)  engine  max_power  seats    brand  model
# 0   First Owner               23.40  1248.0      74.00    5.0   Maruti  Swift
# 1  Second Owner               21.14  1498.0     103.52    5.0    Skoda  Rapid
# 2   Third Owner               17.70  1497.0      78.00    5.0    Honda   City
# 3   First Owner               23.00  1396.0      90.00    5.0  Hyundai    i20
# 4   First Owner               16.10  1298.0      88.20    5.0   Maruti  Swift

# %% [markdown]
# #### 'brand' column ####

# %%
def add_brand(inpt):
    if inpt == 'Land' or inpt == 'Force' or inpt == 'Isuzu' or inpt == 'Ambassador' or inpt == 'Kia' or inpt == 'MG' or inpt == 'Daewoo' or inpt == 'Ashok' or inpt == 'Opel' or inpt == 'Peugeot':
        return 'Other'
    else:
        return inpt

data['brand'] = data['brand'].apply(add_brand)

# %%
data['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Other              34
# Jeep               31
# Mitsubishi         14
# Name: count, dtype: int64

# %% [markdown]
# #### 'model' column ####

# %%
data['model'].value_counts()
# Out:
# model
# Swift     782
# Alto      420
# i20       341
# Wagon     282
# Innova    235
#          ...
# 309         1
# MU          1
# GLC         1
# XC60        1
# S90         1
# Name: count, Length: 207, dtype: int64

# %%
def add_model(inpt):
    if inpt == 'Bolt' or inpt == 'Triber' or inpt == 'Pulse' or inpt == 'Classic' or inpt == 'A4' or inpt == 'Quanto' or inpt == 'BRV' or inpt == 'Pajero' or inpt == 'Aveo' or inpt == 'Yaris' or inpt == 'Qualis' or inpt == 'Punto' or inpt == 'Aria' or inpt == 'Accord' or inpt == 'A6' or inpt == 'Wrangler' or inpt == 'Rover' or inpt == 'Q7' or inpt == 'Platinum' or inpt == 'Gypsy' or inpt == 'Renault' or inpt == 'GLA' or inpt == 'Captiva' or inpt == 'Q3' or inpt == 'Lancer' or inpt == 'Sonata' or inpt == 'Jeep' or inpt == '6' or inpt == 'BR-V' or inpt == 'Passat' or inpt == 'Avventura' or inpt == 'M-Class' or inpt == 'Ssangyong' or inpt == 'Superb' or inpt == 'Estilo' or inpt == 'Santa' or inpt == 'Fluence' or inpt == 'Captur' or inpt == 'S-Class' or inpt == 'Glanza' or inpt == 'B' or inpt == 'Harrier' or inpt == 'NuvoSport' or inpt == 'Kicks' or inpt == 'Venture' or inpt == 'GL-Class' or inpt == 'One' or inpt == 'Seltos' or inpt == 'Hector' or inpt == 'Palio' or inpt == 'Logan' or inpt == 'A3' or inpt == 'Venue' or inpt == 'XL6' or inpt == 'Matiz' or inpt == 'Laura' or inpt == 'Fusion' or inpt == 'Dzire' or inpt == 'Scala' or inpt == 'Supro' or inpt == 'Koleos' or inpt == 'CLA' or inpt == 'Tucson' or inpt == 'MUX' or inpt == '7' or inpt == 'X6' or inpt == 'Kodiaq' or inpt == 'D-Max' or inpt == 'CrossPolo' or inpt == 'S-Presso' or inpt == 'S60' or inpt == 'Xenon' or inpt == 'Gurkha' or inpt == 'XC90' or inpt == 'GTI' or inpt == 'Willys' or inpt == 'Premio' or inpt == 'Yeti' or inpt == 'Ingenio' or inpt == 'X7' or inpt == 'Teana' or inpt == 'CLASSIC' or inpt == 'Winger' or inpt == 'Astra' or inpt == 'Multivan' or inpt == 'Leyland' or inpt == 'Estate' or inpt == 'Marshal' or inpt == 'X3' or inpt == 'Spacio' or inpt == 'Land' or inpt == 'X5' or inpt == 'Trailblazer' or inpt == '309' or inpt == 'MU' or inpt == 'GLC' or inpt == 'XC60' or inpt == 'S90':
        return 'Other'
    else:
        return inpt

data['model'] = data['model'].apply(add_model)

# %%
data['model'].value_counts()
# Out:
# model
# Swift     782
# Alto      420
# Other     373
# i20       341
# Wagon     282
#          ...
# X1         11
# Fabia      11
# Q5         10
# XUV300     10
# Ikon       10
# Name: count, Length: 110, dtype: int64

# %%
data.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner  mileage(km/ltr/kg)  engine  max_power  seats    brand  model
# 0   First Owner               23.40  1248.0      74.00    5.0   Maruti  Swift
# 1  Second Owner               21.14  1498.0     103.52    5.0    Skoda  Rapid
# 2   Third Owner               17.70  1497.0      78.00    5.0    Honda   City
# 3   First Owner               23.00  1396.0      90.00    5.0  Hyundai    i20
# 4   First Owner               16.10  1298.0      88.20    5.0   Maruti  Swift

# %% [markdown]
# #### 'year' column ####

# %%
data['car_age'] = 2026 - data['year']

# %%
data.drop('year', axis=1, inplace=True)

# %%
data.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage(km/ltr/kg)  engine  max_power  seats    brand  model  car_age
# 0               23.40  1248.0      74.00    5.0   Maruti  Swift       12
# 1               21.14  1498.0     103.52    5.0    Skoda  Rapid       12
# 2               17.70  1497.0      78.00    5.0    Honda   City       20
# 3               23.00  1396.0      90.00    5.0  Hyundai    i20       16
# 4               16.10  1298.0      88.20    5.0   Maruti  Swift       19

# %% [markdown]
# #### 'fuel' column ####

# %%
data['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
def add_fuel(inpt):
    if inpt == 'CNG' or inpt == 'LPG':
        return 'Other'
    else:
        return inpt

data['fuel'] = data['fuel'].apply(add_fuel)

# %%
data.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage(km/ltr/kg)  engine  max_power  seats    brand  model  car_age
# 0               23.40  1248.0      74.00    5.0   Maruti  Swift       12
# 1               21.14  1498.0     103.52    5.0    Skoda  Rapid       12
# 2               17.70  1497.0      78.00    5.0    Honda   City       20
# 3               23.00  1396.0      90.00    5.0  Hyundai    i20       16
# 4               16.10  1298.0      88.20    5.0   Maruti  Swift       19

# %% [markdown]
# ### One-Hot Encoding ###

# %%
data = pd.get_dummies(data, drop_first=True)

# %% [markdown]
# ## Devide dataset ##

# %%
x = data.drop('selling_price', axis=1)
y = data['selling_price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(model, x_train, x_test, y_train, y_test):
    
    # Train model
    model.fit(x_train, y_train)
    
    # Predictions
    y_pred = model.predict(x_test)
    
    # Metrics
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print results
    print("Model:", model.__class__.__name__)
    print("R2 Score:", round(r2, 4))
    print("MAE:", round(mae, 2))
    print("RMSE:", round(rmse, 2))
    print("-" * 40)
    
    return r2, mae, rmse

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

models = [
    LinearRegression(),
    RandomForestRegressor(),
    XGBRegressor()
]

for model in models:
    evaluate_model(model, x_train, x_test, y_train, y_test)
# Out:
# Model: LinearRegression
# R2 Score: 0.8488
# MAE: 126641.98
# RMSE: 297555.78
# ----------------------------------------
# Model: RandomForestRegressor
# R2 Score: 0.9692
# MAE: 63224.86
# RMSE: 134362.12
# ----------------------------------------
# Model: XGBRegressor
# R2 Score: 0.971
# MAE: 60650.7
# RMSE: 130346.79
# ----------------------------------------

# %% [markdown]
# #### Check the overfitting ####

# %%
print("Train R2:", model.score(x_train, y_train))
print("Test R2:", model.score(x_test, y_test))
# Out:
# Train R2: 0.9943380355834961
# Test R2: 0.970984935760498

# %% [markdown]
# #### Accuracy Comparison ####

# %%
import pandas as pd

data = {
    "Model": ["Linear Regression", "Random Forest", "XGBoost"],
    "R2": [0.9194, 0.9787, 0.9790],
    "MAE": [116655.58, 62585.16, 61185.52],
    "RMSE": [223170.99, 114674.67, 114039.21]
}

df_results = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(df_results["Model"], df_results["R2"])
plt.title("Model Comparison - R2 Score")
plt.xlabel("Models")
plt.ylabel("R2 Score")
plt.xticks(rotation=20)
plt.show()

# %%
plt.figure()
plt.bar(df_results["Model"], df_results["MAE"])
plt.title("Model Comparison - MAE")
plt.xlabel("Models")
plt.ylabel("MAE")
plt.xticks(rotation=20)
plt.show()

# %%
plt.figure()
plt.bar(df_results["Model"], df_results["RMSE"])
plt.title("Model Comparison - RMSE")
plt.xlabel("Models")
plt.ylabel("RMSE")
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# #### I choose XGBRegressor ####

# %%
model = XGBRegressor()
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
import pickle

with open("model.pkl", "wb") as file:
    pickle.dump(model, file)

# %%
import pickle

with open("x_train_columns.pkl", "wb") as f:
    pickle.dump(x_train.columns.tolist(), f)
    
print("Training columns saved successfully!")
# Out:
# Training columns saved successfully!

# %%
x_train.columns
# Out:
# Index(['km_driven', 'mileage(km/ltr/kg)', 'engine', 'max_power', 'seats',
#        'car_age', 'fuel_Other', 'fuel_Petrol', 'seller_type_Individual',
#        'seller_type_Trustmark Dealer',
#        ...
#        'model_XE', 'model_XF', 'model_XUV300', 'model_XUV500', 'model_Xcent',
#        'model_Xylo', 'model_Zen', 'model_Zest', 'model_i10', 'model_i20'],
#       dtype='object', length=146)

# %%
def predict_car_price(car_data):
    """
    Predict car price based on input features.
    
    Parameters should match the training features exactly.
    """
    input_df = pd.DataFrame([car_data])
    
    for col in x_train.columns:
        if col not in input_df.columns:
            input_df[col] = 0  
    
    input_df = input_df[x_train.columns]  
    
    prediction = model.predict(input_df)[0]
    return prediction

test_car = {
    
    'km_driven': 50000,
    'mileage(km/ltr/kg)': 18.5,
    'engine': 1498.0,
    'max_power': 88.0,
    'seats': 5.0,
    'car_age': 5,
    
    'fuel_Diesel': 1,      
    'fuel_Petrol': 0,     
    
    'seller_type_Individual': 1,  
    
    'transmission_Manual': 1,      
    
    'owner_First Owner': 0,
    'owner_Second Owner': 1,
    'owner_Third Owner': 0,
    'owner_Test Drive Car': 0,
    
    'brand_Maruti': 0,
    'brand_Hyundai': 1,
    'brand_Mahindra': 0,
    'brand_Tata': 0,
    'brand_Toyota': 0,
    'brand_Honda': 0,
    'brand_Ford': 0,
    'brand_Chevrolet': 0,
    'brand_Renault': 0,
    'brand_Volkswagen': 0,
    'brand_BMW': 0,
    'brand_Skoda': 0,
    'brand_Nissan': 0,
    'brand_Jaguar': 0,
    'brand_Volvo': 0,
    'brand_Datsun': 0,
    'brand_Mercedes-Benz': 0,
    'brand_Fiat': 0,
    'brand_Audi': 0,
    'brand_Lexus': 0,
    'brand_Other': 0,
    'brand_Jeep': 0,
    'brand_Mitsubishi': 0,
    
    'model_Swift': 0,
    'model_Alto': 0,
    'model_Other': 0,
    'model_i20': 1,
    'model_Wagon': 0,
    'model_Innova': 0,
    'model_Bolero': 0,
    'model_Verna': 0,
    'model_Grand': 0,
    'model_City': 0,
    'model_Scorpio': 0,
    'model_Figo': 0,
    'model_Indica': 0,
    'model_Ertiga': 0,
    'model_XUV500': 0,
    'model_Indigo': 0,
    'model_i10': 0,
    'model_Santro': 0,
    'model_EON': 0,
    'model_Baleno': 0,
    'model_Etios': 0,
    'model_KWID': 0,
    'model_Amaze': 0,
    'model_800': 0,
    'model_Creta': 0,
    'model_Vitara': 0,
    'model_Xcent': 0,
    'model_EcoSport': 0,
    'model_Ritz': 0,
    'model_Polo': 0,
    'model_Duster': 0,
    'model_Jazz': 0,
    'model_Tiago': 0,
    'model_Ciaz': 0,
    'model_Rapid': 0,
    'model_Beat': 0,
    'model_Safari': 0,
    'model_Zen': 0,
    'model_Celerio': 0,
    'model_X4': 0,
    'model_Vento': 0,
    'model_Fiesta': 0,
    'model_TUV': 0,
    'model_Manza': 0,
    'model_Eeco': 0,
    'model_New': 0,
    'model_Omni': 0,
    'model_Xylo': 0,
    'model_SX4': 0,
    'model_Fortuner': 0,
    'model_KUV': 0,
    'model_Zest': 0,
    'model_Spark': 0,
    'model_XF': 0,
    'model_GO': 0,
    'model_Nexon': 0,
    'model_Corolla': 0,
    'model_Camry': 0,
    'model_ES': 0,
    'model_Sumo': 0,
    'model_Accent': 0,
    'model_XC40': 0,
    'model_Elite': 0,
    'model_XE': 0,
    'model_V40': 0,
    'model_Sail': 0,
    'model_Ameo': 0,
    'model_Tigor': 0,
    'model_Sunny': 0,
    'model_Ignis': 0,
    'model_Micra': 0,
    'model_Brio': 0,
    'model_Ecosport': 0,
    'model_RediGO': 0,
    'model_Tavera': 0,
    'model_Compass': 0,
    'model_Terrano': 0,
    'model_Thar': 0,
    'model_Nano': 0,
    'model_Enjoy': 0,
    'model_WR-V': 0,
    'model_Verito': 0,
    'model_Hexa': 0,
    'model_Endeavour': 0,
    'model_3': 0,
    'model_S-Cross': 0,
    'model_Grande': 0,
    'model_A-Star': 0,
    'model_Cruze': 0,
    'model_Octavia': 0,
    'model_Civic': 0,
    'model_5': 0,
    'model_E-Class': 0,
    'model_Freestyle': 0,
    'model_Mobilio': 0,
    'model_Linea': 0,
    'model_Elantra': 0,
    'model_Getz': 0,
    'model_Lodgy': 0,
    'model_Marazzo': 0,
    'model_Jetta': 0,
    'model_Aspire': 0,
    'model_Esteem': 0,
    'model_CR-V': 0,
    'model_Optra': 0,
    'model_X1': 0,
    'model_Fabia': 0,
    'model_Q5': 0,
    'model_XUV300': 0,
    'model_Ikon': 0,
}

predicted = predict_car_price(test_car)
print(f"Predicted price: Rs.{predicted:,.2f}")
# Out:
# Predicted price: Rs.664,728.19
